# %% [markdown]
# # MSDS 422 Assignment 1 - Exploring and Visualizing Data:
#
# This assignment focuses on bringing data into Python, exploring and visualizing data. You will need to install Python on your personal computer (Mac or Windows) prior to working on this assignment. See Python installation instructions under Modules / Technology Resources / Software for Practical Machine Learning (Python version).
#
# As part of this assignment, you are asked to choose a variable with meaningful magnitude and examine the effects of two transformations (scaling methods) on that variable.
#
# Formatting Python Code
# Refer to Google’s Python Style Guide (https://google.github.io/styleguide/pyguide.html) for ideas about formatting Python code:
#
# Comment often and in detail, highlighting major sections of code, describing the thinking behind the modeling and programming methods being employed.
#
# #### Background Materials
# COVID 19 is an ongoing threat.  Data for the outbreak are available here:  https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide (Links to an external site.)
#
# Using this data, you are to conduct exploratory data analysis.  Provide appropriate descriptive statistics  / visualizations to help understand the spread of the disease (incidence) as well as its fatality rate.  You should also engage in feature creation and variable transformation.  At a bare minimum, feature creation should include generating rates per X in the population (i.e., rates per million).  Investigate time series as well as univariate and bivariate distribution graphs.
#
# Select one of variable and perform both min-max and standard scaling in Python.  See https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html#sphx-glr-auto-examples-preprocessing-plot-all-scaling-py (Links to an external site.)
#
#  (Some methods we will learn in this course  (trees and random forests) are unaffected by monotonic transformations of the explanatory variables. Others (SVMs and neural networks) are very much affected by scaling and usually perform better when all explanatory variables have the same scale. It is often best to use scaling methods that preserve the shape of the distribution. But if there are extreme outliers or heavily skewed distributions, then log or normalizing transformations may be warranted.)
#
#  #### Table of Contents
#  - Data preparation (10 points)
#  - Data exploration (10 points) & Data Visualization (10 points)
#  - Data scaling and comparisons (10 points)
#  - Insights from analysis (10 points)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy as sp
import sklearn

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

from IPython.display import display
from IPython.display import HTML
import datetime as dt

today = dt.datetime.today().strftime("%d %b %Y")

# %% [markdown]
# Download the data from opendata.ecdc.europa.eu

# %%
# load the data
rawdata = pd.read_csv("https://opendata.ecdc.europa.eu/covid19/casedistribution/csv")

# %% [markdown]
# Prepare and clean the data
# - drop NaN and NA
# - convert the columns: dateRep to datetime64, popData2019 to int64
# - fix dateRep not as a good date using the month, day, and year columns to construct a datetime
# - limit the data set to only recent data, will include all data less than and including today
# - cases and deaths should be greater than or equal to 0

# %%
# clean the data
#   -- eliminate NA's
data = rawdata.dropna()

#   -- redo data types of some columns
data = data.astype({ 'dateRep': 'datetime64', 'popData2019': "int64" })

#   -- fix dateRep not as a good date using the month, day, and year columns to construct a datetime
def fixdate(m,d,y):
    return pd.to_datetime(str(m) + "/" + str(d) + "/" + str(y))

data['dateRep'] = data.apply(lambda x: fixdate(x.month, x.day, x.year), axis=1)

#   -- limit the data set to only recent data, will include all data less than and including today
data = data[data['dateRep'] < pd.to_datetime('today')]

#  -- cases and deaths should be greater than or equal to 0
data = data[(data['cases'] >= 0) & (data['deaths'] >= 0)]

# %% [markdown]
# Inspect the data after preparation and cleanup

# %%
data.shape
# Out:
# (25129, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25129 entries, 0 to 25307
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  25129 non-null  datetime64[ns]
#  1   day                      25129 non-null  int64
#  2   month                    25129 non-null  int64
#  3   year                     25129 non-null  int64
#  4   cases                    25129 non-null  int64
#  5   deaths                   25129 non-null  int64
#  6   countriesAndTerritories  25129 non-null  object
#  7   geoId                    25129 non-null  object
#  8   countryterritoryCode     25129 non-null  object
#  9   popData2019              25129 non-null  int64
#  10  continentExp             25129 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(4)
# memory usage: 2.3+ MB

# %%
data.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-06-23   23      6  2020    310      17             Afghanistan    AF
# 1 2020-06-22   22      6  2020    409      12             Afghanistan    AF
# 2 2020-06-21   21      6  2020    546      21             Afghanistan    AF
# 3 2020-06-20   20      6  2020    346       2             Afghanistan    AF
# 4 2020-06-19   19      6  2020    658      42             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp
# 0                  AFG     38041757         Asia
# 1                  AFG     38041757         Asia
# 2                  AFG     38041757         Asia
# 3                  AFG     38041757         Asia
# 4                  AFG     38041757         Asia

# %%
data[data['countriesAndTerritories'] == 'United_States_of_America'].head()
# Out:
#          dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 24242 2020-06-23   23      6  2020  31390     427  United_States_of_America
# 24243 2020-06-22   22      6  2020  25793     256  United_States_of_America
# 24244 2020-06-21   21      6  2020  34158     607  United_States_of_America
# 24245 2020-06-20   20      6  2020  29909     678  United_States_of_America
# 24246 2020-06-19   19      6  2020  27762     717  United_States_of_America
#
#       geoId countryterritoryCode  popData2019 continentExp
# 24242    US                  USA    329064917      America
# 24243    US                  USA    329064917      America
# 24244    US                  USA    329064917      America
# 24245    US                  USA    329064917      America
# 24246    US                  USA    329064917      America

# %% [markdown]
# ## Data exploration (10 points) & Data Visualization (10 points)

# %%
data.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp'],
#       dtype='object')

# %% [markdown]
# #### Exploration - Step 1: Sum of Cases, Sum of Deaths, Fatality Rate, Reported Cases per 100,000 population,  Reported Deaths per 100,000 population -- By Continent + Country/Territory

# %%
# set rate / rates per 100,000
population = 100000

def get_facts(attr = 'countriesAndTerritories', population=100000, f_rate = 100):
    # get the cumulative cases and deaths by countries and territories
    cumulative_cases_deaths = data.groupby(['continentExp',attr]).\
            agg({'cases': 'sum', 'deaths': 'sum', 'popData2019': 'max'}).reset_index()#.groupby(level=0).cumsum().reset_index()

    # rename columns
    cumulative_cases_deaths.rename(columns={'cases': 'Sum of Cases', 'deaths': 'Sum of Deaths', \
                                    'popData2019': 'Population'}, inplace=True)


    # function to compute the features of:
    #   fatality_rate
    #   fatality_rate_per_100000
    #   case_rate_per_100000
    def get_features(x):
        d = {}

        d['Fatality Rate'] = x['Sum of Deaths'] / x['Sum of Cases'] * f_rate
        d['Reported Cases per 100 000 population'] = x['Sum of Cases'] / x['Population'] * population
        d['Reported Deaths per 100 000 population'] = x['Sum of Deaths'] / x['Population'] * population    

        return pd.Series(d, index=['Fatality Rate', 'Reported Cases per 100 000 population', \
                                   'Reported Deaths per 100 000 population'])

    # join the data cumulative cases and deaths with the computed features
    cumulative_cases_deaths_add_features = cumulative_cases_deaths.\
        join(cumulative_cases_deaths.apply(get_features, axis=1))
    
    return cumulative_cases_deaths_add_features

cumulative_cases_deaths_add_features = get_facts()

# %%
# limit columns to display in table
col_display_list = ['countriesAndTerritories', 'Sum of Cases', 'Sum of Deaths', 'Population',\
                   'Fatality Rate', 'Reported Cases per 100 000 population', \
                    'Reported Deaths per 100 000 population']

# create a summary table per continent
for c in cumulative_cases_deaths_add_features.continentExp.unique():
    # copy dataframe into a new one for display
    exp1 = cumulative_cases_deaths_add_features
    # limit the continent to the filter from loop 
    exp1 = exp1[exp1.continentExp == c]
    # limit the columns to the list contained in col_display_list
    exp1 = exp1[col_display_list]
    exp1.sort_values(by='Sum of Cases', ascending=False, inplace=True)
    # get the grand totals for: Sum of Cases, Sum of Deaths, and Population
    exp1_grand_total = pd.DataFrame(exp1.sum(axis=0),columns=['Grand Total'])
    exp1_grand_total.iloc[[0,4,5,6]] = ''
    exp1_display = pd.concat([exp1,exp1_grand_total.T])
    
    #display
    #. Header
    display(HTML("<b>" + c + "</b>"))
    #. Summary - cases
    summary_cases = 'As of ' + today + ', <b>' + "{:,}".format(exp1['Sum of Cases'].sum()) + ' cases</b> have been reported in ' + \
        c + ': ' + \
        ', '.join([str(r['countriesAndTerritories']) + ' (' + str(r['Sum of Cases']) + ')' for i, r in exp1.iterrows()]) + \
        '.'
     #. Summary - deaths
    summary_deaths = 'As of ' + today + ', <b>' + "{:,}".format(exp1['Sum of Deaths'].sum()) + ' deaths</b> have been reported in ' + \
        c + ': ' + \
        ', '.join([str(r['countriesAndTerritories']) + ' (' + str(r['Sum of Deaths']) + ')' for i, r in exp1.iterrows()]) + \
        '.'
    #. Show
    display(HTML(summary_cases))
    display(HTML(summary_deaths))
    display(exp1_display)
# Out:
# <b>Africa</b>
# As of 23 Jun 2020, <b>315,523 cases</b> have been reported in Africa: South_Africa (101590), Egypt (56809), Nigeria (20919), Ghana (14154), Algeria (11920), Cameroon (11892), Morocco (10172), Sudan (8698), Cote_dIvoire (7492), Senegal (5970), Democratic_Republic_of_the_Congo (5925), Guinea (4988), Kenya (4797), Gabon (4739), Ethiopia (4663), Djibouti (4599), Mauritania (2984), Central_African_Republic (2963), Somalia (2812), Equatorial_Guinea (2001), Mali (1961), South_Sudan (1892), Madagascar (1640), Guinea_Bissau (1556), Zambia (1430), Sierra_Leone (1340), Tunisia (1159), Congo (1087), Niger (1046), Benin (1016), Cape_Verde (944), Burkina_Faso (907), Uganda (890), Chad (858), Malawi (803), Rwanda (787), Mozambique (737), Sao_Tome_and_Principe (702), Liberia (650), Eswatini (643), Libya (571), Togo (569), Zimbabwe (512), United_Republic_of_Tanzania (509), Mauritius (340), Comoros (247), Angola (183), Burundi (144), Eritrea (143), Botswana (89), Gambia (41), Western_Sahara (25), Seychelles (11), Lesotho (4).
# As of 23 Jun 2020, <b>8,329 deaths</b> have been reported in Africa: South_Africa (1991), Egypt (2278), Nigeria (525), Ghana (85), Algeria (852), Cameroon (303), Morocco (214), Sudan (533), Cote_dIvoire (54), Senegal (86), Democratic_Republic_of_the_Congo (135), Guinea (27), Kenya (125), Gabon (39), Ethiopia (75), Djibouti (48), Mauritania (111), Central_African_Republic (30), Somalia (90), Equatorial_Guinea (32), Mali (111), South_Sudan (34), Madagascar (15), Guinea_Bissau (19), Zambia (11), Sierra_Leone (55), Tunisia (50), Congo (37), Niger (67), Benin (13), Cape_Verde (8), Burkina_Faso (53), Uganda (0), Chad (74), Malawi (11), Rwanda (2), Mozambique (5), Sao_Tome_and_Principe (12), Liberia (34), Eswatini (6), Libya (10), Togo (13), Zimbabwe (6), United_Republic_of_Tanzania (21), Mauritius (10), Comoros (5), Angola (9), Burundi (1), Eritrea (0), Botswana (1), Gambia (2), Western_Sahara (1), Seychelles (0), Lesotho (0).
#                       countriesAndTerritories Sum of Cases Sum of Deaths  \
# 44                               South_Africa       101590          1991
# 15                                      Egypt        56809          2278
# 37                                    Nigeria        20919           525
# 22                                      Ghana        14154            85
# 0                                     Algeria        11920           852
# 6                                    Cameroon        11892           303
# 34                                    Morocco        10172           214
# 46                                      Sudan         8698           533
# 12                               Cote_dIvoire         7492            54
# 40                                    Senegal         5970            86
# 13           Democratic_Republic_of_the_Congo         5925           135
# 23                                     Guinea         4988            27
# 25                                      Kenya         4797           125
# 20                                      Gabon         4739            39
# 19                                   Ethiopia         4663            75
# 14                                   Djibouti         4599            48
# 32                                 Mauritania         2984           111
# 8                    Central_African_Republic         2963            30
# 43                                    Somalia         2812            90
# 16                          Equatorial_Guinea         2001            32
# 31                                       Mali         1961           111
# 45                                South_Sudan         1892            34
# 29                                 Madagascar         1640            15
# 24                              Guinea_Bissau         1556            19
# 52                                     Zambia         1430            11
# 42                               Sierra_Leone         1340            55
# 48                                    Tunisia         1159            50
# 11                                      Congo         1087            37
# 36                                      Niger         1046            67
# 2                                       Benin         1016            13
# 7                                  Cape_Verde          944             8
# 4                                Burkina_Faso          907            53
# 49                                     Uganda          890             0
# 9                                        Chad          858            74
# 30                                     Malawi          803            11
# 38                                     Rwanda          787             2
# 35                                 Mozambique          737             5
# 39                      Sao_Tome_and_Principe          702            12
# 27                                    Liberia          650            34
# 18                                   Eswatini          643             6
# 28                                      Libya          571            10
# 47                                       Togo          569            13
# 53                                   Zimbabwe          512             6
# 50                United_Republic_of_Tanzania          509            21
# 33                                  Mauritius          340            10
# 10                                    Comoros          247             5
# 1                                      Angola          183             9
# 5                                     Burundi          144             1
# 17                                    Eritrea          143             0
# 3                                    Botswana           89             1
# 21                                     Gambia           41             2
# 51                             Western_Sahara           25             1
# 41                                 Seychelles           11             0
# 26                                    Lesotho            4             0
# Grand Total                                         315523          8329
#
#              Population Fatality Rate Reported Cases per 100 000 population  \
# 44             58558267       1.95984                               173.485
# 15            100388076       4.00993                               56.5894
# 37            200963603       2.50968                               10.4093
# 22             30417858      0.600537                               46.5319
# 0              43053054       7.14765                               27.6868
# 6              25876387       2.54793                                45.957
# 34             36471766       2.10381                               27.8901
# 46             42813237       6.12785                               20.3161
# 12             25716554      0.720769                                29.133
# 40             16296362       1.44054                               36.6339
# 13             86790568       2.27848                               6.82678
# 23             12771246      0.541299                               39.0565
# 25             52573967        2.6058                               9.12429
# 20              2172578      0.822958                               218.128
# 19            112078727       1.60841                               4.16047
# 14               973557       1.04371                               472.391
# 32              4525698       3.71984                               65.9346
# 8               4745179       1.01249                               62.4423
# 43             15442906       3.20057                                18.209
# 16              1355982        1.5992                               147.568
# 31             19658023       5.66038                               9.97557
# 45             11062114       1.79704                               17.1034
# 29             26969306      0.914634                               6.08099
# 24              1920917       1.22108                                81.003
# 52             17861034      0.769231                               8.00626
# 42              7813207       4.10448                               17.1504
# 48             11694721       4.31406                               9.91045
# 11              5380504       3.40386                               20.2026
# 36             23310719       6.40535                               4.48721
# 2              11801151       1.27953                               8.60933
# 7                549936      0.847458                               171.656
# 4              20321383       5.84344                               4.46328
# 49             44269587             0                               2.01041
# 9              15946882       8.62471                               5.38036
# 30             18628749       1.36986                               4.31054
# 38             12626938       0.25413                               6.23271
# 35             30366043      0.678426                               2.42705
# 39               215048        1.7094                               326.439
# 27              4937374       5.23077                               13.1649
# 18              1148133      0.933126                                56.004
# 28              6777453       1.75131                               8.42499
# 47              8082359       2.28471                               7.04002
# 53             14645473       1.17188                               3.49596
# 50             58005461       4.12574                              0.877504
# 33              1269670       2.94118                               26.7786
# 10               850891       2.02429                               29.0284
# 1              31825299       4.91803                              0.575014
# 5              11530577      0.694444                               1.24885
# 17              3497117             0                               4.08908
# 3               2303703        1.1236                               3.86335
# 21              2347696       4.87805                               1.74639
# 51               567402             4                               4.40605
# 41                97741             0                               11.2542
# 26              2125267             0                              0.188212
# Grand Total  1304393450
#
#             Reported Deaths per 100 000 population
# 44                                         3.40003
# 15                                         2.26919
# 37                                        0.261241
# 22                                        0.279441
# 0                                          1.97895
# 6                                          1.17095
# 34                                        0.586755
# 46                                         1.24494
# 12                                        0.209981
# 40                                        0.527725
# 13                                        0.155547
# 23                                        0.211412
# 25                                         0.23776
# 20                                          1.7951
# 19                                       0.0669172
# 14                                         4.93037
# 32                                         2.45266
# 8                                         0.632221
# 43                                        0.582792
# 16                                         2.35991
# 31                                        0.564655
# 45                                        0.307355
# 29                                       0.0556188
# 24                                        0.989111
# 52                                       0.0615866
# 42                                        0.703936
# 48                                        0.427543
# 11                                        0.687668
# 36                                        0.287421
# 2                                         0.110159
# 7                                          1.45471
# 4                                         0.260809
# 49                                               0
# 9                                         0.464041
# 30                                       0.0590485
# 38                                       0.0158392
# 35                                       0.0164658
# 39                                         5.58015
# 27                                        0.688625
# 18                                        0.522588
# 28                                        0.147548
# 47                                        0.160844
# 53                                       0.0409683
# 50                                       0.0362035
# 33                                        0.787606
# 10                                        0.587619
# 1                                        0.0282794
# 5                                       0.00867259
# 17                                               0
# 3                                        0.0434084
# 21                                       0.0851899
# 51                                        0.176242
# 41                                               0
# 26                                               0
# Grand Total
# <b>America</b>
# As of 23 Jun 2020, <b>4,516,766 cases</b> have been reported in America: United_States_of_America (2312302), Brazil (1106470), Peru (254936), Chile (246963), Mexico (185122), Canada (101637), Colombia (71183), Ecuador (54631), Argentina (44918), Dominican_Republic (27370), Panama (26752), Bolivia (25493), Guatemala (13769), Honduras (13356), Puerto_Rico (6564), Haiti (5211), El_Salvador (4808), Venezuela (4048), Cuba (2315), Costa_Rica (2277), Nicaragua (2014), Paraguay (1392), Uruguay (882), Jamaica (665), Suriname (319), Guyana (205), Cayman_Islands (195), Bermuda (146), Trinidad_and_Tobago (123), Bahamas (104), Aruba (101), Barbados (97), Sint_Maarten (77), United_States_Virgin_Islands (76), Saint_Vincent_and_the_Grenadines (29), Antigua_and_Barbuda (26), Grenada (23), Belize (23), Curaçao (23), Saint_Lucia (19), Dominica (18), Saint_Kitts_and_Nevis (15), Turks_and_Caicos_islands (14), Greenland (13), Falkland_Islands_(Malvinas) (13), Montserrat (11), British_Virgin_Islands (8), Bonaire, Saint Eustatius and Saba (7), Anguilla (3).
# As of 23 Jun 2020, <b>226,328 deaths</b> have been reported in America: United_States_of_America (120402), Brazil (51271), Peru (8045), Chile (4502), Mexico (22584), Canada (8436), Colombia (2310), Ecuador (4106), Argentina (1043), Dominican_Republic (669), Panama (521), Bolivia (820), Guatemala (547), Honduras (395), Puerto_Rico (149), Haiti (88), El_Salvador (107), Venezuela (35), Cuba (85), Costa_Rica (12), Nicaragua (64), Paraguay (13), Uruguay (25), Jamaica (10), Suriname (8), Guyana (12), Cayman_Islands (1), Bermuda (9), Trinidad_and_Tobago (8), Bahamas (11), Aruba (3), Barbados (7), Sint_Maarten (15), United_States_Virgin_Islands (6), Saint_Vincent_and_the_Grenadines (0), Antigua_and_Barbuda (3), Grenada (0), Belize (2), Curaçao (1), Saint_Lucia (0), Dominica (0), Saint_Kitts_and_Nevis (0), Turks_and_Caicos_islands (1), Greenland (0), Falkland_Islands_(Malvinas) (0), Montserrat (1), British_Virgin_Islands (1), Bonaire, Saint Eustatius and Saba (0), Anguilla (0).
#                        countriesAndTerritories Sum of Cases Sum of Deaths  \
# 100                   United_States_of_America      2312302        120402
# 64                                      Brazil      1106470         51271
# 90                                        Peru       254936          8045
# 68                                       Chile       246963          4502
# 85                                      Mexico       185122         22584
# 66                                      Canada       101637          8436
# 69                                    Colombia        71183          2310
# 75                                     Ecuador        54631          4106
# 56                                   Argentina        44918          1043
# 74                          Dominican_Republic        27370           669
# 88                                      Panama        26752           521
# 62                                     Bolivia        25493           820
# 80                                   Guatemala        13769           547
# 83                                    Honduras        13356           395
# 91                                 Puerto_Rico         6564           149
# 82                                       Haiti         5211            88
# 76                                 El_Salvador         4808           107
# 102                                  Venezuela         4048            35
# 71                                        Cuba         2315            85
# 70                                  Costa_Rica         2277            12
# 87                                   Nicaragua         2014            64
# 89                                    Paraguay         1392            13
# 101                                    Uruguay          882            25
# 84                                     Jamaica          665            10
# 96                                    Suriname          319             8
# 81                                      Guyana          205            12
# 67                              Cayman_Islands          195             1
# 61                                     Bermuda          146             9
# 97                         Trinidad_and_Tobago          123             8
# 58                                     Bahamas          104            11
# 57                                       Aruba          101             3
# 59                                    Barbados           97             7
# 95                                Sint_Maarten           77            15
# 99                United_States_Virgin_Islands           76             6
# 94            Saint_Vincent_and_the_Grenadines           29             0
# 55                         Antigua_and_Barbuda           26             3
# 79                                     Grenada           23             0
# 60                                      Belize           23             2
# 72                                     Curaçao           23             1
# 93                                 Saint_Lucia           19             0
# 73                                    Dominica           18             0
# 92                       Saint_Kitts_and_Nevis           15             0
# 98                    Turks_and_Caicos_islands           14             1
# 78                                   Greenland           13             0
# 77                 Falkland_Islands_(Malvinas)           13             0
# 86                                  Montserrat           11             1
# 65                      British_Virgin_Islands            8             1
# 63           Bonaire, Saint Eustatius and Saba            7             0
# 54                                    Anguilla            3             0
# Grand Total                                         4516766        226328
#
#              Population Fatality Rate Reported Cases per 100 000 population  \
# 100           329064917       5.20702                               702.689
# 64            211049519       4.63375                                524.27
# 90             32510462       3.15569                               784.166
# 68             18952035       1.82295                               1303.09
# 85            127575529       12.1995                               145.108
# 66             37411038       8.30013                               271.677
# 69             50339443       3.24516                               141.406
# 75             17373657       7.51588                               314.447
# 56             44780675       2.32201                               100.307
# 74             10738957       2.44428                               254.866
# 88              4176869       1.94752                                640.48
# 62             11513102       3.21657                               221.426
# 80             17581476       3.97269                               78.3154
# 83              9746115       2.95747                               137.039
# 91              2933404       2.26996                               223.767
# 82             11263079       1.68874                               46.2662
# 76              6453055       2.22546                               74.5073
# 102            28515829      0.864625                               14.1956
# 71             11333484       3.67171                               20.4262
# 70              5047561      0.527009                               45.1109
# 87              6545503       3.17776                               30.7692
# 89              7044639      0.933908                               19.7597
# 101             3461731       2.83447                               25.4786
# 84              2948277       1.50376                               22.5555
# 96               581363       2.50784                               54.8711
# 81               782775       5.85366                               26.1889
# 67                64948      0.512821                                300.24
# 61                62508       6.16438                                233.57
# 97              1394969       6.50407                                8.8174
# 58               389486       10.5769                               26.7019
# 57               106031        2.9703                               95.2552
# 59               287021       7.21649                               33.7954
# 95                40654       19.4805                               189.403
# 99               104579       7.89474                               72.6723
# 94               110593             0                               26.2223
# 55                97115       11.5385                               26.7724
# 79               112002             0                               20.5353
# 60               390351       8.69565                               5.89213
# 72               163423       4.34783                               14.0739
# 93               182795             0                               10.3942
# 73                71808             0                               25.0668
# 92                52834             0                               28.3908
# 98                38194       7.14286                                36.655
# 78                56660             0                               22.9439
# 77                 3372             0                               385.528
# 86                 4991       9.09091                               220.397
# 65                30033          12.5                               26.6374
# 63                25983             0                               26.9407
# 54                14872             0                               20.1721
# Grand Total  1013529716
#
#             Reported Deaths per 100 000 population
# 100                                        36.5891
# 64                                         24.2934
# 90                                         24.7459
# 68                                         23.7547
# 85                                         17.7025
# 66                                         22.5495
# 69                                         4.58885
# 75                                         23.6335
# 56                                         2.32913
# 74                                         6.22966
# 88                                         12.4735
# 62                                         7.12232
# 80                                         3.11123
# 83                                          4.0529
# 91                                         5.07942
# 82                                        0.781314
# 76                                         1.65813
# 102                                       0.122739
# 71                                         0.74999
# 70                                        0.237739
# 87                                        0.977771
# 89                                        0.184537
# 101                                       0.722182
# 84                                        0.339181
# 96                                         1.37608
# 81                                         1.53301
# 67                                         1.53969
# 61                                         14.3982
# 97                                        0.573489
# 58                                         2.82424
# 57                                         2.82936
# 59                                         2.43885
# 95                                         36.8967
# 99                                         5.73729
# 94                                               0
# 55                                         3.08912
# 79                                               0
# 60                                        0.512359
# 72                                        0.611909
# 93                                               0
# 73                                               0
# 92                                               0
# 98                                         2.61821
# 78                                               0
# 77                                               0
# 86                                         20.0361
# 65                                         3.32967
# 63                                               0
# 54                                               0
# Grand Total
# <b>Asia</b>
# As of 23 Jun 2020, <b>1,909,165 cases</b> have been reported in Asia: India (440215), Iran (207525), Turkey (188897), Pakistan (185034), Saudi_Arabia (161005), Bangladesh (115786), Qatar (88403), China (84624), Indonesia (46845), United_Arab_Emirates (45303), Singapore (42313), Kuwait (40291), Iraq (32676), Oman (31076), Philippines (30682), Afghanistan (29143), Bahrain (22407), Israel (21082), Kazakhstan (18231), Japan (17968), South_Korea (12484), Nepal (9026), Malaysia (8587), Uzbekistan (6500), Tajikistan (5513), Kyrgyzstan (3519), Thailand (3151), Maldives (2217), Sri_Lanka (1951), Lebanon (1603), Palestine (1196), Jordan (1042), Yemen (967), Taiwan (446), Vietnam (349), Myanmar (291), Syria (219), Mongolia (215), Brunei_Darussalam (141), Cambodia (130), Bhutan (69), Timor_Leste (24), Laos (19).
# As of 23 Jun 2020, <b>48,601 deaths</b> have been reported in Asia: India (14011), Iran (9742), Turkey (4974), Pakistan (3695), Saudi_Arabia (1307), Bangladesh (1502), Qatar (99), China (4639), Indonesia (2500), United_Arab_Emirates (303), Singapore (26), Kuwait (330), Iraq (1167), Oman (137), Philippines (1177), Afghanistan (598), Bahrain (65), Israel (307), Kazakhstan (127), Japan (955), South_Korea (281), Nepal (23), Malaysia (121), Uzbekistan (19), Tajikistan (52), Kyrgyzstan (41), Thailand (58), Maldives (8), Sri_Lanka (11), Lebanon (32), Palestine (5), Jordan (9), Yemen (257), Taiwan (7), Vietnam (0), Myanmar (6), Syria (7), Mongolia (0), Brunei_Darussalam (3), Cambodia (0), Bhutan (0), Timor_Leste (0), Laos (0).
#             countriesAndTerritories Sum of Cases Sum of Deaths  Population  \
# 110                           India       440215         14011  1366417756
# 112                            Iran       207525          9742    82913893
# 141                          Turkey       188897          4974    83429607
# 128                        Pakistan       185034          3695   216565317
# 132                    Saudi_Arabia       161005          1307    34268529
# 105                      Bangladesh       115786          1502   163046173
# 131                           Qatar        88403            99     2832071
# 109                           China        84624          4639  1433783692
# 111                       Indonesia        46845          2500   270625567
# 142            United_Arab_Emirates        45303           303     9770526
# 133                       Singapore        42313            26     5804343
# 118                          Kuwait        40291           330     4207077
# 113                            Iraq        32676          1167    39309789
# 127                            Oman        31076           137     4974992
# 130                     Philippines        30682          1177   108116622
# 103                     Afghanistan        29143           598    38041757
# 104                         Bahrain        22407            65     1641164
# 114                          Israel        21082           307     8519373
# 117                      Kazakhstan        18231           127    18551428
# 115                           Japan        17968           955   126860299
# 134                     South_Korea        12484           281    51225321
# 126                           Nepal         9026            23    28608715
# 122                        Malaysia         8587           121    31949789
# 143                      Uzbekistan         6500            19    32981715
# 138                      Tajikistan         5513            52     9321023
# 119                      Kyrgyzstan         3519            41     6415851
# 139                        Thailand         3151            58    69625581
# 123                        Maldives         2217             8      530957
# 135                       Sri_Lanka         1951            11    21323734
# 121                         Lebanon         1603            32     6855709
# 129                       Palestine         1196             5     4981422
# 116                          Jordan         1042             9    10101697
# 145                           Yemen          967           257    29161922
# 137                          Taiwan          446             7    23780452
# 144                         Vietnam          349             0    96462108
# 125                         Myanmar          291             6    54045422
# 136                           Syria          219             7    17070132
# 124                        Mongolia          215             0     3225166
# 107               Brunei_Darussalam          141             3      433296
# 108                        Cambodia          130             0    16486542
# 106                          Bhutan           69             0      763094
# 140                     Timor_Leste           24             0     1293120
# 120                            Laos           19             0     7169456
# Grand Total                              1909165         48601  4543492199
#
#             Fatality Rate Reported Cases per 100 000 population  \
# 110               3.18276                               32.2167
# 112               4.69437                                250.29
# 141               2.63318                               226.415
# 128               1.99693                               85.4403
# 132              0.811776                               469.833
# 105               1.29722                               71.0142
# 131              0.111987                                3121.5
# 109                5.4819                               5.90215
# 111               5.33675                               17.3099
# 142               0.66883                                463.67
# 133             0.0614468                               728.989
# 118              0.819041                               957.696
# 113               3.57143                               83.1243
# 127              0.440855                               624.644
# 130               3.83613                               28.3786
# 103               2.05195                               76.6079
# 104              0.290088                               1365.31
# 114               1.45622                                247.46
# 117              0.696616                               98.2728
# 115                 5.315                               14.1636
# 134               2.25088                               24.3708
# 126              0.254819                               31.5498
# 122               1.40911                               26.8765
# 143              0.292308                               19.7079
# 138              0.943225                               59.1459
# 119                1.1651                               54.8485
# 139               1.84069                               4.52564
# 123              0.360848                               417.548
# 135              0.563813                               9.14943
# 121               1.99626                                23.382
# 129               0.41806                               24.0092
# 116              0.863724                               10.3151
# 145                26.577                               3.31597
# 137               1.56951                               1.87549
# 144                     0                                0.3618
# 125               2.06186                              0.538436
# 136               3.19635                               1.28294
# 124                     0                               6.66632
# 107               2.12766                               32.5413
# 108                     0                              0.788522
# 106                     0                               9.04214
# 140                     0                               1.85598
# 120                     0                              0.265013
# Grand Total
#
#             Reported Deaths per 100 000 population
# 110                                        1.02538
# 112                                        11.7495
# 141                                        5.96191
# 128                                        1.70618
# 132                                          3.814
# 105                                       0.921211
# 131                                        3.49568
# 109                                        0.32355
# 111                                       0.923786
# 142                                        3.10116
# 133                                        0.44794
# 118                                        7.84393
# 113                                        2.96873
# 127                                        2.75377
# 130                                        1.08864
# 103                                        1.57196
# 104                                         3.9606
# 114                                        3.60355
# 117                                       0.684583
# 115                                       0.752797
# 134                                       0.548557
# 126                                      0.0803951
# 122                                       0.378719
# 143                                      0.0576077
# 138                                       0.557879
# 119                                       0.639042
# 139                                      0.0833027
# 123                                        1.50671
# 135                                      0.0515857
# 121                                       0.466764
# 129                                       0.100373
# 116                                      0.0890939
# 145                                       0.881286
# 137                                      0.0294359
# 144                                              0
# 125                                      0.0111018
# 136                                      0.0410073
# 124                                              0
# 107                                       0.692367
# 108                                              0
# 106                                              0
# 140                                              0
# 120                                              0
# Grand Total
# <b>Europe</b>
# As of 23 Jun 2020, <b>2,319,164 cases</b> have been reported in Europe: Russia (592280), United_Kingdom (305814), Spain (247589), Italy (238868), Germany (190862), France (161516), Belgium (60550), Belarus (59023), Sweden (58932), Netherlands (49658), Portugal (39553), Ukraine (37241), Poland (32227), Switzerland (31310), Ireland (25383), Romania (24291), Armenia (20588), Austria (17320), Moldova (14363), Azerbaijan (13207), Serbia (12990), Denmark (12527), Czechia (10561), Norway (8745), Finland (7144), North_Macedonia (5196), Luxembourg (4121), Hungary (4107), Bulgaria (3984), Bosnia_and_Herzegovina (3524), Greece (3287), Croatia (2336), Kosovo (2169), Albania (1995), Estonia (1981), Lithuania (1906), Iceland (1823), Slovakia (1588), Slovenia (1521), Latvia (1111), Cyprus (988), Georgia (911), Andorra (855), San_Marino (722), Malta (665), Montenegro (367), Isle_of_Man (336), Jersey (318), Guernsey (252), Faroe_Islands (187), Gibraltar (176), Monaco (101), Liechtenstein (83), Holy_See (12).
# As of 23 Jun 2020, <b>189,140 deaths</b> have been reported in Europe: Russia (8206), United_Kingdom (42284), Spain (29832), Italy (34610), Germany (8895), France (29556), Belgium (9696), Belarus (351), Sweden (5122), Netherlands (6090), Portugal (1518), Ukraine (1012), Poland (1359), Switzerland (1680), Ireland (1717), Romania (1523), Armenia (360), Austria (690), Moldova (480), Azerbaijan (161), Serbia (262), Denmark (602), Czechia (336), Norway (248), Finland (327), North_Macedonia (247), Luxembourg (110), Hungary (573), Bulgaria (207), Bosnia_and_Herzegovina (170), Greece (190), Croatia (107), Kosovo (37), Albania (44), Estonia (69), Lithuania (73), Iceland (10), Slovakia (28), Slovenia (109), Latvia (30), Cyprus (19), Georgia (14), Andorra (52), San_Marino (42), Malta (9), Montenegro (9), Isle_of_Man (24), Jersey (31), Guernsey (13), Faroe_Islands (0), Gibraltar (0), Monaco (5), Liechtenstein (1), Holy_See (0).
#             countriesAndTerritories Sum of Cases Sum of Deaths Population  \
# 190                          Russia       592280          8206  114587226
# 199                  United_Kingdom       305814         42284   66647112
# 195                           Spain       247589         29832   46937060
# 173                           Italy       238868         34610   60359546
# 164                         Germany       190862          8895   83019213
# 162                          France       161516         29556   67012883
# 152                         Belgium        60550          9696   11455519
# 151                         Belarus        59023           351    9452409
# 196                          Sweden        58932          5122   10230185
# 184                     Netherlands        49658          6090   17282163
# 188                        Portugal        39553          1518   10276617
# 198                         Ukraine        37241          1012   43993643
# 187                          Poland        32227          1359   37972812
# 197                     Switzerland        31310          1680    8591361
# 171                         Ireland        25383          1717    4904240
# 189                         Romania        24291          1523   19414458
# 148                         Armenia        20588           360    2957728
# 149                         Austria        17320           690    8858775
# 181                         Moldova        14363           480    4043258
# 150                      Azerbaijan        13207           161   10047719
# 192                          Serbia        12990           262    8772228
# 158                         Denmark        12527           602    5806081
# 157                         Czechia        10561           336   10649800
# 186                          Norway         8745           248    5328212
# 161                         Finland         7144           327    5517919
# 185                 North_Macedonia         5196           247    2083458
# 179                      Luxembourg         4121           110     613894
# 169                         Hungary         4107           573    9772756
# 154                        Bulgaria         3984           207    7000039
# 153          Bosnia_and_Herzegovina         3524           170    3300998
# 166                          Greece         3287           190   10724599
# 155                         Croatia         2336           107    4076246
# 175                          Kosovo         2169            37    1845300
# 146                         Albania         1995            44    2880913
# 159                         Estonia         1981            69    1324820
# 178                       Lithuania         1906            73    2759631
# 170                         Iceland         1823            10     356991
# 193                        Slovakia         1588            28    5450421
# 194                        Slovenia         1521           109    2080908
# 176                          Latvia         1111            30    1919968
# 156                          Cyprus          988            19     875899
# 163                         Georgia          911            14    3996762
# 147                         Andorra          855            52      77146
# 191                      San_Marino          722            42      33864
# 180                           Malta          665             9     493559
# 183                      Montenegro          367             9     627988
# 172                     Isle_of_Man          336            24      84589
# 174                          Jersey          318            31     106800
# 167                        Guernsey          252            13      62792
# 160                   Faroe_Islands          187             0      48497
# 165                       Gibraltar          176             0      33706
# 182                          Monaco          101             5      38967
# 177                   Liechtenstein           83             1      38020
# 168                        Holy_See           12             0        815
# Grand Total                              2319164        189140  736828513
#
#             Fatality Rate Reported Cases per 100 000 population  \
# 190               1.38549                               516.881
# 199               13.8267                               458.856
# 195                12.049                               527.491
# 173               14.4892                               395.742
# 164               4.66044                               229.901
# 162               18.2991                               241.022
# 152               16.0132                               528.566
# 151              0.594683                               624.423
# 196               8.69137                                576.06
# 184               12.2639                               287.337
# 188               3.83789                               384.883
# 198               2.71744                               84.6509
# 187               4.21696                               84.8686
# 197                5.3657                               364.436
# 171               6.76437                               517.573
# 189               6.26981                               125.118
# 148               1.74859                               696.075
# 149               3.98383                               195.512
# 181               3.34192                               355.233
# 150               1.21905                               131.443
# 192               2.01694                               148.081
# 158               4.80562                               215.757
# 157               3.18152                               99.1662
# 186               2.83591                               164.126
# 161               4.57727                               129.469
# 185               4.75366                               249.393
# 179               2.66926                               671.289
# 169               13.9518                                42.025
# 154               5.19578                                56.914
# 153               4.82406                               106.756
# 166               5.78035                               30.6492
# 155               4.58048                               57.3076
# 175               1.70586                               117.542
# 146               2.20551                               69.2489
# 159               3.48309                                149.53
# 178               3.83001                               69.0672
# 170              0.548546                               510.657
# 193               1.76322                               29.1354
# 194               7.16634                               73.0931
# 176               2.70027                               57.8655
# 156               1.92308                               112.798
# 163               1.53677                               22.7935
# 147               6.08187                               1108.29
# 191               5.81717                               2132.06
# 180               1.35338                               134.736
# 183               2.45232                               58.4406
# 172               7.14286                               397.215
# 174               9.74843                               297.753
# 167               5.15873                               401.325
# 160                     0                               385.591
# 165                     0                               522.162
# 182                4.9505                               259.194
# 177               1.20482                               218.306
# 168                     0                               1472.39
# Grand Total
#
#             Reported Deaths per 100 000 population
# 190                                        7.16136
# 199                                        63.4446
# 195                                        63.5575
# 173                                        57.3397
# 164                                        10.7144
# 162                                         44.105
# 152                                        84.6404
# 151                                        3.71334
# 196                                        50.0675
# 184                                        35.2386
# 188                                        14.7714
# 198                                        2.30033
# 187                                        3.57888
# 197                                        19.5545
# 171                                        35.0105
# 189                                        7.84467
# 148                                        12.1715
# 149                                        7.78889
# 181                                        11.8716
# 150                                        1.60235
# 192                                         2.9867
# 158                                        10.3684
# 157                                        3.15499
# 186                                        4.65447
# 161                                        5.92615
# 185                                        11.8553
# 179                                        17.9184
# 169                                        5.86324
# 154                                        2.95713
# 153                                        5.14996
# 166                                        1.77163
# 155                                        2.62496
# 175                                        2.00509
# 146                                        1.52729
# 159                                        5.20825
# 178                                        2.64528
# 170                                        2.80119
# 193                                       0.513722
# 194                                         5.2381
# 176                                        1.56253
# 156                                         2.1692
# 163                                       0.350284
# 147                                        67.4047
# 191                                        124.026
# 180                                        1.82349
# 183                                        1.43315
# 172                                        28.3725
# 174                                        29.0262
# 167                                        20.7033
# 160                                              0
# 165                                              0
# 182                                        12.8314
# 177                                        2.63019
# 168                                              0
# Grand Total
# <b>Oceania</b>
# As of 23 Jun 2020, <b>9,002 cases</b> have been reported in Oceania: Australia (7474), New_Zealand (1165), Guam (225), French_Polynesia (60), Northern_Mariana_Islands (30), New_Caledonia (21), Fiji (18), Papua_New_Guinea (9).
# As of 23 Jun 2020, <b>131 deaths</b> have been reported in Oceania: Australia (102), New_Zealand (22), Guam (5), French_Polynesia (0), Northern_Mariana_Islands (2), New_Caledonia (0), Fiji (0), Papua_New_Guinea (0).
#               countriesAndTerritories Sum of Cases Sum of Deaths Population  \
# 200                         Australia         7474           102   25203200
# 205                       New_Zealand         1165            22    4783062
# 203                              Guam          225             5     167295
# 202                  French_Polynesia           60             0     279285
# 206          Northern_Mariana_Islands           30             2      57213
# 204                     New_Caledonia           21             0     282757
# 201                              Fiji           18             0     889955
# 207                  Papua_New_Guinea            9             0    8776119
# Grand Total                                   9002           131   40438886
#
#             Fatality Rate Reported Cases per 100 000 population  \
# 200               1.36473                                29.655
# 205               1.88841                               24.3568
# 203               2.22222                               134.493
# 202                     0                               21.4834
# 206               6.66667                               52.4356
# 204                     0                               7.42687
# 201                     0                               2.02257
# 207                     0                              0.102551
# Grand Total
#
#             Reported Deaths per 100 000 population
# 200                                       0.404711
# 205                                       0.459956
# 203                                        2.98873
# 202                                              0
# 206                                        3.49571
# 204                                              0
# 201                                              0
# 207                                              0
# Grand Total

# %% [markdown]
# #### Exploration - Step 2: Distribution of cases and deaths of COVID-19 -- By Continent + Country/Territory

# %%
# generate distributions
distributions = data.groupby(['continentExp', 'countriesAndTerritories', 'dateRep']).\
    agg({'cases': 'sum', 'deaths': 'sum'}).reset_index()

def plot_distribution(feature):
    x = pd.DataFrame(distributions.dateRep.unique(), columns=['dateRep'])
    np.random.seed(0)

    # loop through each continent and plot cases by country
    for c in distributions.continentExp.unique():
        plt.cla()   # Clear axis
        plt.clf()   # Clear figure
        plt.close() # Close a figure window

        fig, axs = plt.subplots(1, 1, figsize=(15,15)) # make the figure with the size 20 x 20 inches
        width = 0.4

        exp2_source = distributions[distributions['continentExp'] == c]

        axes = []
        legendLabels = []

        for ct in exp2_source.countriesAndTerritories.unique():
            exp2 = exp2_source[(exp2_source['continentExp'] == c) & \
                               (exp2_source['countriesAndTerritories'] == ct)]
            values = {'continentExp': c, 'countriesAndTerritories': ct, 'cases': 0, 'deaths': 0}
            exp2_display = pd.merge(x, exp2, on='dateRep', how='left').fillna(value=values)
            axes.append(axs.bar(exp2_display['dateRep'], exp2_display[feature], color = np.random.rand(3,)))
            legendLabels.append(ct) 

        fig.suptitle('Distribution of ' + feature + ' of COVID-19 in ' + c + ', as of ' + today, fontsize=22)
        fig.legend(labels=legendLabels, 
                   loc="lower center",
                   borderaxespad=0.1,
                   title="Countries/Territories",
                   fontsize = 14,
                   ncol=8)      

        plt.xlabel('Date', fontsize=14)
        plt.ylabel('Cases', fontsize=14)
        plt.subplots_adjust(bottom=0.25)
        plt.grid(True)
        axs.tick_params(axis='x', which='major', labelsize=14, rotation=45)
        axs.tick_params(axis='y', which='major', labelsize=14)
        display(plt.show())
        
plot_distribution('cases')
plot_distribution('deaths')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# #### Exploration - Step 3: Distribution of cases and deaths of COVID-19 -- Top 10 cases

# %%
# generate distributions
distributions = data.groupby(['continentExp', 'countriesAndTerritories', 'dateRep']).\
    agg({'cases': 'sum', 'deaths': 'sum'}).reset_index()

top10cases = cumulative_cases_deaths_add_features.sort_values(by='Sum of Cases', ascending=False).head(10)
top10distributions = distributions[distributions['countriesAndTerritories'].\
                                   isin(top10cases.countriesAndTerritories.values)]

# %%
def plot_distribution(feature):
    x = pd.DataFrame(distributions.dateRep.unique(), columns=['dateRep'])
    np.random.seed(0)
    
    # loop through each continent and plot cases by country
    for ct in top10distributions.countriesAndTerritories.unique():
        exp2_source = top10distributions[top10distributions['countriesAndTerritories'] == ct]
        
        plt.cla()   # Clear axis
        plt.clf()   # Clear figure
        plt.close() # Close a figure window

        fig, axs = plt.subplots(1, 1, figsize=(12,4)) # make the figure with the size 20 x 20 inches
        width = 0.4

        axes = []

        exp2 = exp2_source[exp2_source['countriesAndTerritories'] == ct]
        values = {'countriesAndTerritories': ct, 'cases': 0, 'deaths': 0}
        exp2_display = pd.merge(x, exp2, on='dateRep', how='left').fillna(value=values)
        axes.append(axs.bar(exp2_display['dateRep'], exp2_display[feature], color = 'orange', edgecolor='k'))

        fig.suptitle('Distribution of ' + feature + ' of COVID-19 in ' + ct + ', as of ' + today, fontsize=18)   

        plt.xlabel('Date', fontsize=14)
        plt.ylabel('Cases', fontsize=14)
        plt.subplots_adjust(bottom=0.25)
        plt.grid(True)
        axs.tick_params(axis='x', which='major', labelsize=14, rotation=45)
        axs.tick_params(axis='y', which='major', labelsize=14)
        display(plt.show())
        
plot_distribution('cases')
plot_distribution('deaths')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# #### Exploration - Step 4: What is the fatality ratio across the countries/territories?

# %%
cumulative_cases_deaths_add_features = get_facts('countryterritoryCode', 1, 1)

# %%
#cumulative_cases_deaths_add_features

plt.cla()   # Clear axis
plt.clf()   # Clear figure
plt.close() # Close a figure window

fr, x = [], []

for i,s in enumerate(cumulative_cases_deaths_add_features['countryterritoryCode']):
    cc = cumulative_cases_deaths_add_features['countryterritoryCode'].iloc[i]
    r = np.round(cumulative_cases_deaths_add_features['Fatality Rate'].iloc[i],3)
    x.append(cc)
    fr.append(r)

fr = np.array(fr)
plt.figure(figsize=(15,12))
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)

plt.title("Fatality ratio across the countries/territories",fontsize=18)
plt.scatter(x=x,
            y=fr,
            s=2e5*fr**2,
            color='orange',edgecolor='red',alpha=0.75,linewidth=2.5)

for i,s in enumerate(x):
    plt.annotate(s=s,xy=(x[i],fr[i]))

plt.ylim(-0.03,0.35)
plt.yticks(fontsize=16)
plt.grid(True,axis='y')
plt.show()

# %% [markdown]
# #### Exploration - Step 5: Is the death count incresing with the rate of cases in the US?
#
# Countries investigated:
# - United_Kingdom
# - Spain
# - Italy
# - Germany
# - France
# - Russia
# - India
# - Iran
# - Turkey
# - Pakistan
# - China
# - United_States_of_America
# - Brazil
# - Peru
# - Chile
# - Mexico
# - Canada
# - South_Africa
# - Egypt

# %%
# generate distributions
distributions = data.groupby(['continentExp', 'countriesAndTerritories', 'dateRep']).\
    agg({'cases': 'sum', 'deaths': 'sum'}).reset_index()

# %%
# Function to create scatter plot of two variables for a given country/territory
def plot_xy(varx='cases',
            vary='deaths',
            attr='United_States_of_America'):
    """
    Plots a bar chart of the given variable over the date range
    """
    assert type(varx)==str, "Expected string as the variable x name"
    assert type(vary)==str, "Expected string as the variable y name"
    
    plt.cla()   # Clear axis
    plt.clf()   # Clear figure
    plt.close() # Close a figure window
 
    y = distributions[distributions['countriesAndTerritories']==attr][vary]
    x = distributions[distributions['countriesAndTerritories']==attr][varx]
    if (x.nunique()!=1) and (y.nunique()!=1):
        plt.figure(figsize=(12,4))
        plt.title("Plot of \"{}\" vs. \"{}\" for {}".format(varx,vary,attr),fontsize=18)
        plt.scatter(x=x,y=y,edgecolor='k',color='lightgreen',s=100)
        plt.grid(True)
        plt.tick_params(axis='x', which='major', labelsize=14, rotation=45)
        plt.tick_params(axis='y', which='major', labelsize=14)
        plt.show()
    else:
        print("Some of the data unavailable for a scatter plot. Sorry!")

# %%
c_list = ['United_Kingdom', 'Spain', 'Italy', 'Germany', 'France', 'Russia', 'India', 'Iran', 'Turkey', 
    'Pakistan', 'China', 'United_States_of_America', 'Brazil', 'Peru', 'Chile', 'Mexico', 'Canada', 
    'South_Africa','Egypt']

for c in c_list:
    display(plot_xy(attr=c))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ### Data scaling and comparisons (10 points)
# #### 'Fatality Rate Variable' Transformation using Scikit Learn

# %%
variable = get_facts()

# %%
def create_plot(x_attr, y_attr, plot_type):
    x = variable[x_attr]
    y = np.array(variable[y_attr]).reshape(-1,1)
    
    if(plot_type == 'Unscaled'):
        y = variable[y_attr]
    elif(plot_type == 'StandardScaler'):
        y = StandardScaler().fit_transform(y)
    elif(plot_type == 'MinMaxScaler'):
        y = MinMaxScaler().fit_transform(y)
    elif(plot_type == 'MaxAbsScaler'):
        y = MaxAbsScaler().fit_transform(y)
    elif(plot_type == 'RobustScaler'):
        y = RobustScaler(quantile_range=(25, 75)).fit_transform(y)
    elif(plot_type == 'PowerTransformer-yeo-johnson'):
        y = PowerTransformer(method='yeo-johnson').fit_transform(y)
    elif(plot_type == 'sample-wise L2 normalizing'):
        y = Normalizer().fit_transform(y)
        
    
    plt.cla()   # Clear axis
    plt.clf()   # Clear figure
    plt.close() # Close a figure window

    plt.figure(figsize=(12,4))
    plt.title('{} {}'.format(y_attr, plot_type),fontsize=18)
    plt.scatter(x=x,y=y,edgecolor='k',color='lightgreen',s=100)
    plt.grid(True)
    plt.tick_params(axis='x', which='major', labelsize=14, rotation=45)
    plt.tick_params(axis='y', which='major', labelsize=14)
    plt.show()

# %%
display(create_plot('Population', 'Fatality Rate', 'Unscaled'))
display(create_plot('Population', 'Fatality Rate', 'StandardScaler'))
display(create_plot('Population', 'Fatality Rate', 'MinMaxScaler'))
display(create_plot('Population', 'Fatality Rate', 'MaxAbsScaler'))
display(create_plot('Population', 'Fatality Rate', 'RobustScaler'))
display(create_plot('Population', 'Fatality Rate', 'PowerTransformer-yeo-johnson'))
display(create_plot('Population', 'Fatality Rate', 'sample-wise L2 normalizing'))
# Out:
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ### Insights from analysis (10 points)

# %% [markdown]
# Put Insights Here
